# %% [markdown]
# <a href="https://colab.research.google.com/github/spinto499-ctrl/FUNPRO-QUESTS/blob/main/Clase_2_Listas_y_diccionarios.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Indicar cuántos n constructores tienen más experiencia que el promedio

# %% [markdown]
# Soluciones

# %%
n1=14600
n2=21200
n3=32400
n4=51000
n5=10000

promedio=(n1+n2+n3+n4+n5)/5

if n1>promedio: print("El estudiante 1 sacó más que el promedio")
elif n2>promedio: print("El estudiante 1 sacó más que el promedio")
elif n3>promedio: print("El estudiante 1 sacó más que el promedio")
elif n4>promedio: print("El estudiante 1 sacó más que el promedio")
else: print("El estudiante 5 sacó más que el promedio")
# Out:
# El estudiante 1 sacó más que el promedio

# %% [markdown]
# #LISTAS
# Son un tipo de dato **mutable**, que permite almacenar incontable cantidad de elementos. Todos lo eslementos dento de la lista se separan con comas.
#
# Sintaxis
# ```
# # Crear listas
# variable=[]
# ```

# %% [markdown]
# .append():
#
# Agrega un nuevo elemento a la lista.

# %%
n=5
estudiantes=[]
for i in range(1,n+1):
  estudiante=int(input(f"Ingrese la experiencia del estudiante {i} "))
  estudiantes.append(estudiante)

  promedio=sum(estudiantes)/len(estudiantes)
# Out:
# Ingrese la experiencia del estudiante 1 4
# Ingrese la experiencia del estudiante 2 1
# Ingrese la experiencia del estudiante 3 6
# Ingrese la experiencia del estudiante 4 8
# Ingrese la experiencia del estudiante 5 7

# %%
for i in range(1,len(estudiantes)): #len cuenta cantidad de elementos
  if estudiantes[i]>promedio:
    print(f"El estudiante {i} tiene más experiencia que el promedio")
# Out:
# El estudiante 2 tiene más experiencia que el promedio
# El estudiante 3 tiene más experiencia que el promedio
# El estudiante 4 tiene más experiencia que el promedio

# %%
hash(i)#Rastrea el dato inmutable
# Out:
# 4

# %%
hola1=estudiantes
hola2=estudiantes.copy()

# %% [markdown]
# .count
# Count cuenta cuántas veces está el elemento en una lista

# %%
dineros=250000
compras=[]
precios=[]
while dineros>0:
  compras.append(input("Qué quieres introducir en la canasta?: "))
  precio=(int(input("Cuánto cuesta el producto: ")))
  precios.append(precio)
  dineros=dineros-precio
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_1612/414554994.py in <cell line: 0>()
#       3 precios=[]
#       4 while dineros>0:
# ----> 5   compras.append(input("Qué quieres introducir en la canasta?: "))
#       6   precio=(int(input("Cuánto cuesta el producto: ")))
#       7   precios.append(precio)
#
# /usr/local/lib/python3.13/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.13/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
# ...

# %%
dineros=250000
compras=[]
precios=[]
while dineros>0:
  compras.append(input("Qué quieres introducir en la canasta?: "))
  precio=(int(input("Cuánto cuesta el producto: ")))
  precios.append(precio)
  dineros=dineros-precio
  continuar=(int(input("Quieres seguir comprando?: ")))
  if dineros<=0 or continuar.lower()=="sí" or continuar.lower()=="si":
    break
# Out:
# Qué quieres introducir en la canasta?: kiwi
# Cuánto cuesta el producto: 7000
# Quieres seguir comprando?: no
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_666/2989386692.py in <cell line: 0>()
#       7   precios.append(precio)
#       8   dineros=dineros-precio
# ----> 9   continuar=(int(input("Quieres seguir comprando?: ")))
#      10   if dineros<=0 or continuar.lower()=="sí" or continuar.lower()=="si":
#      11     break
#
# ValueError: invalid literal for int() with base 10: 'no'

# %% [markdown]
# ![image.png](data:image/png;base64,...)
